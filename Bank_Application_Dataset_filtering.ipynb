# %%
import numpy as np 
import pandas as pd

# %%
dt=pd.read_csv('Customer-Records.csv')
dt
# Out:
#     RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 0           1    15647311        Hill          608  Female   41       1
# 1           2    15619304        Onio          502  Female   42       8
# 2           3    15737888    Mitchell          850  Female   43       2
# 3           4    15574012     Jagdale          645    Male   18       8
# 4           5    15656148       Pawar          376  Female   19       4
# 5           6    15792365          He          501    Male   44       4
# 6           7    15592389          H?          684    Male   27       2
# 7           8    15767821      Bearce          528    Male   31       6
# 8           9    15643966     Goforth          616    Male   45       3
# 9          10    15737452       Romeo          653    Male   58       1
# 10         11    15736816       Patil          756    Male   25       2
# 11         12    15728693  McWilliams          574  Female   43       3
# ...

# %%
dt.drop(100, inplace=True)
dt
# Out:
#     RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 0           1    15634602    Hargrave          619  Female   42       2
# 1           2    15647311        Hill          608  Female   41       1
# 2           3    15619304        Onio          502  Female   42       8
# 3           4    15701354        Boni          699  Female   39       1
# 4           5    15737888    Mitchell          850  Female   43       2
# ..        ...         ...         ...          ...     ...  ...     ...
# 95         96    15699461  Fiorentini          515    Male   35      10
# 96         97    15738721      Graham          773    Male   41       9
# 97         98    15693683      Yuille          814    Male   29       8
# 98         99    15604348      Allard          710    Male   22       8
# 99        100    15633059     Fanucci          413    Male   34       9
#
#       Balance  NumOfProducts Card Type  Point Earned
# ...

# %%
import random
dt['Password'] = dt['Surname'] + dt.apply(lambda row: str(random.randint(1000, 9999)), axis=1)
dt
# Out:
#     RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 0           1    15634602    Hargrave          619  Female   42       2
# 1           2    15647311        Hill          608  Female   41       1
# 2           3    15619304        Onio          502  Female   42       8
# 3           4    15701354        Boni          699  Female   39       1
# 4           5    15737888    Mitchell          850  Female   43       2
# ..        ...         ...         ...          ...     ...  ...     ...
# 95         96    15699461  Fiorentini          515    Male   35      10
# 96         97    15738721      Graham          773    Male   41       9
# 97         98    15693683      Yuille          814    Male   29       8
# 98         99    15604348      Allard          710    Male   22       8
# 99        100    15633059     Fanucci          413    Male   34       9
#
#       Balance  NumOfProducts Card Type  Point Earned        Password
# ...

# %%
dt.drop(dt[dt.Balance < 500].index, axis=0, inplace=True)
dt
# Out:
#     RowNumber  CustomerId        Surname  CreditScore  Gender  Age  Tenure  \
# 1           2    15647311           Hill          608  Female   41       1
# 2           3    15619304           Onio          502  Female   42       8
# 4           5    15737888       Mitchell          850  Female   43       2
# 5           6    15574012            Chu          645    Male   44       8
# 7           8    15656148         Obinna          376  Female   29       4
# 8           9    15792365             He          501    Male   44       4
# 9          10    15592389             H?          684    Male   27       2
# 10         11    15767821         Bearce          528    Male   31       6
# 15         16    15643966        Goforth          616    Male   45       3
# 16         17    15737452          Romeo          653    Male   58       1
# 26         27    15736816          Young          756    Male   36       2
# ...

# %%
dt
# Out:
#     RowNumber  CustomerId        Surname  CreditScore  Gender  Age  Tenure  \
# 1           2    15647311           Hill          608  Female   41       1
# 2           3    15619304           Onio          502  Female   42       8
# 4           5    15737888       Mitchell          850  Female   43       2
# 5           6    15574012            Chu          645    Male   44       8
# 7           8    15656148         Obinna          376  Female   29       4
# 8           9    15792365             He          501    Male   44       4
# 9          10    15592389             H?          684    Male   27       2
# 10         11    15767821         Bearce          528    Male   31       6
# 15         16    15643966        Goforth          616    Male   45       3
# 16         17    15737452          Romeo          653    Male   58       1
# 26         27    15736816          Young          756    Male   36       2
# ...

# %%
dt.count()
# Out:
# RowNumber        60
# CustomerId       60
# Surname          60
# CreditScore      60
# Gender           60
# Age              60
# Tenure           60
# Balance          60
# NumOfProducts    60
# Card Type        60
# Point Earned     60
# Password         60
# dtype: int64

# %%
# dt.loc[5,['Surname', 'Age', 'Balance','Password']] = ['Jagdale', 18, 1200000.50,'Jagdale4530']
# dt.loc[7,['Surname', 'Age', 'Balance','Password']] = ['Pawar', 19, 500.00,'Pawar7271']
# dt.loc[26,['Surname', 'Age', 'Balance','Password']] = ['Patil', 25, 50000.80,'Patil4990']
# dt.loc[31,['Surname', 'Age', 'Balance','Password']] = ['Deshmukh', 20, 675000.50,'Deshmukh4405']
# dt.loc[41,['Surname', 'Age', 'Balance','Password']] = ['Kadam', 22, 100000.00,'Kadam9283']
dt
# Out:
#     RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 1           2    15647311        Hill          608  Female   41       1
# 2           3    15619304        Onio          502  Female   42       8
# 4           5    15737888    Mitchell          850  Female   43       2
# 5           6    15574012     Jagdale          645    Male   18       8
# 7           8    15656148       Pawar          376  Female   19       4
# 8           9    15792365          He          501    Male   44       4
# 9          10    15592389          H?          684    Male   27       2
# 10         11    15767821      Bearce          528    Male   31       6
# 15         16    15643966     Goforth          616    Male   45       3
# 16         17    15737452       Romeo          653    Male   58       1
# 26         27    15736816       Patil          756    Male   25       2
# 28         29    15728693  McWilliams          574  Female   43       3
# ...

# %%
dt['RowNumber'] = range(1, len(dt) + 1)
dt.index = range(1, len(dt) + 1)

dt
# Out:
#     RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 1           1    15647311        Hill          608  Female   41       1
# 2           2    15619304        Onio          502  Female   42       8
# 3           3    15737888    Mitchell          850  Female   43       2
# 4           4    15574012     Jagdale          645    Male   18       8
# 5           5    15656148       Pawar          376  Female   19       4
# 6           6    15792365          He          501    Male   44       4
# 7           7    15592389          H?          684    Male   27       2
# 8           8    15767821      Bearce          528    Male   31       6
# 9           9    15643966     Goforth          616    Male   45       3
# 10         10    15737452       Romeo          653    Male   58       1
# 11         11    15736816       Patil          756    Male   25       2
# 12         12    15728693  McWilliams          574  Female   43       3
# ...

# %%
dt.loc[54,'Balance'] = 700.00
dt.loc[43,'Balance'] = 900.00
dt.loc[24,'Balance'] = 670.00
dt
# Out:
#     RowNumber  CustomerId     Surname  CreditScore  Gender  Age  Tenure  \
# 1           1    15647311        Hill          608  Female   41       1
# 2           2    15619304        Onio          502  Female   42       8
# 3           3    15737888    Mitchell          850  Female   43       2
# 4           4    15574012     Jagdale          645    Male   18       8
# 5           5    15656148       Pawar          376  Female   19       4
# 6           6    15792365          He          501    Male   44       4
# 7           7    15592389          H?          684    Male   27       2
# 8           8    15767821      Bearce          528    Male   31       6
# 9           9    15643966     Goforth          616    Male   45       3
# 10         10    15737452       Romeo          653    Male   58       1
# 11         11    15736816       Patil          756    Male   25       2
# 12         12    15728693  McWilliams          574  Female   43       3
# ...

# %%
# dt.to_csv('Customer-Records.csv', index=False)

# %%
dt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dt
#
# NameError: name 'dt' is not defined
